# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np 

import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### Read Data

# %%
data = pd.read_csv("day.csv")
data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %% [markdown]
# ### Data Quality check

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# ### Visualising relationship for numerical variable

# %%
X_var = ['instant','season','dteday','yr','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed']

sns.pairplot(data = data, x_vars=X_var, y_vars='cnt')
plt.show()

# %% [markdown]
# ### Data Encoding

# %%
data = data.drop(['casual','registered','instant','dteday'], axis=1)
data['season'] = data['season'].map({1:'spring', 2:'summer', 3:'fall', 4:'winter'})
data['weathersit'] = data['weathersit'].map({1:'clear', 2:'mist', 3:'light_rain', 4:'heavy_rain'})
data.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday weathersit       temp  \
# 0  spring   0     1        0        6           0       mist  14.110847
# 1  spring   0     1        0        0           0       mist  14.902598
# 2  spring   0     1        0        1           1      clear   8.050924
# 3  spring   0     1        0        2           1      clear   8.200000
# 4  spring   0     1        0        3           1      clear   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %%
# creating dummy variables

data = pd.get_dummies(data = data, columns=['season','weathersit'],drop_first=True, dtype=int, prefix= '', prefix_sep='')
data.head()
# Out:
#    yr  mnth  holiday  weekday  workingday       temp     atemp      hum  \
# 0   0     1        0        6           0  14.110847  18.18125  80.5833
# 1   0     1        0        0           0  14.902598  17.68695  69.6087
# 2   0     1        0        1           1   8.050924   9.47025  43.7273
# 3   0     1        0        2           1   8.200000  10.60610  59.0435
# 4   0     1        0        3           1   9.305237  11.46350  43.6957
#
#    windspeed   cnt  spring  summer  winter  light_rain  mist
# 0  10.749882   985       1       0       0           0     1
# 1  16.652113   801       1       0       0           0     1
# 2  16.636703  1349       1       0       0           0     0
# 3  10.739832  1562       1       0       0           0     0
# 4  12.522300  1600       1       0       0           0     0

# %% [markdown]
# ### Understanding the correlations between different features

# %%
fig, ax = plt.subplots(figsize = (15,10))
sns.heatmap(data.corr(),annot=True, ax = ax)
plt.show()

# %% [markdown]
# ### Split test and train data

# %%
data_train, data_test = train_test_split(data,train_size=0.7, random_state=100)
print(data_train.shape,data_test.shape)
# Out:
# (510, 15) (220, 15)

# %% [markdown]
# ### Scale the necessary feature columns

# %%
scaler = MinMaxScaler()
scale_column = ['mnth','weekday','temp','atemp','hum','windspeed']

data_train[scale_column] = scaler.fit_transform(data_train[scale_column])

data_train.head()
# Out:
#      yr      mnth  holiday   weekday  workingday      temp     atemp  \
# 576   1  0.545455        0  0.333333           1  0.815169  0.766351
# 426   1  0.181818        0  1.000000           0  0.442393  0.438975
# 728   1  1.000000        0  0.000000           0  0.245101  0.200348
# 482   1  0.272727        0  1.000000           0  0.395666  0.391735
# 111   0  0.272727        0  0.833333           1  0.345824  0.318819
#
#           hum  windspeed   cnt  spring  summer  winter  light_rain  mist
# 576  0.725633   0.264686  7216       0       0       0           0     0
# 426  0.640189   0.255342  4066       1       0       0           0     1
# 728  0.498067   0.663106  1796       1       0       0           0     0
# 482  0.504508   0.188475  4220       0       1       0           0     1
# 111  0.751824   0.380981  1683       0       1       0           0     1

# %%
data_train.describe()
# Out:
#                yr        mnth     holiday     weekday  workingday        temp  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.503743    0.025490    0.498366    0.676471    0.537440
# std      0.500429    0.315038    0.157763    0.336182    0.468282    0.225858
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.181818    0.000000    0.166667    0.000000    0.339853
# 50%      1.000000    0.545455    0.000000    0.500000    1.000000    0.542596
# 75%      1.000000    0.818182    0.000000    0.833333    1.000000    0.735215
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#             atemp         hum   windspeed          cnt      spring  \
# count  510.000000  510.000000  510.000000   510.000000  510.000000
# mean     0.513156    0.650480    0.320883  4485.337255    0.243137
# ...

# %% [markdown]
# ### Feature Selection

# %%
y_train = data_train.pop('cnt')
X_train = data_train

# %%
# using automated RFE process

lr = LinearRegression()
lr.fit(X_train,y_train)
rfe = RFE(estimator=lr,n_features_to_select=10)
rfe = rfe.fit(X_train,y_train)

# %%
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('mnth', False, 5),
#  ('holiday', True, 1),
#  ('weekday', False, 2),
#  ('workingday', False, 4),
#  ('temp', True, 1),
#  ('atemp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('spring', True, 1),
#  ('summer', False, 3),
#  ('winter', True, 1),
#  ('light_rain', True, 1),
#  ('mist', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'temp', 'atemp', 'hum', 'windspeed', 'spring',
#        'winter', 'light_rain', 'mist'],
#       dtype='object')

# %%
X_train_rfe = X_train[col]

# %% [markdown]
# ### Linear Model Building

# %%
X_train_sm = sm.add_constant(X_train_rfe)
lm = sm.OLS(y_train,X_train_sm)
lr_model = lm.fit()

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     233.1
# Date:                Wed, 10 Apr 2024   Prob (F-statistic):          6.85e-181
# Time:                        16:09:17   Log-Likelihood:                -4144.3
# No. Observations:                 510   AIC:                             8311.
# Df Residuals:                     499   BIC:                             8357.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2964.3415    282.788     10.483      0.000    2408.740    3519.943
# ...

# %% [markdown]
# #### check VIF for manual feature selection

# %%
vif = pd.DataFrame()
vif['features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values,i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by="VIF", ascending= False)
vif
# Out:
#      features     VIF
# 3       atemp  350.96
# 2        temp  348.31
# 4         hum   22.05
# 5   windspeed    4.03
# 6      spring    2.51
# 9        mist    2.24
# 7      winter    2.10
# 0          yr    2.05
# 8  light_rain    1.21
# 1     holiday    1.04

# %% [markdown]
# ### Fine tune the model through hybrid approach

# %%
X_train_rfe = X_train_rfe.drop('atemp',axis = 1)
X_train_sm = sm.add_constant(X_train_rfe)
lm = sm.OLS(y_train,X_train_sm)
lr_model = lm.fit()

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     259.1
# Date:                Wed, 10 Apr 2024   Prob (F-statistic):          5.75e-182
# Time:                        16:09:17   Log-Likelihood:                -4144.7
# No. Observations:                 510   AIC:                             8309.
# Df Residuals:                     500   BIC:                             8352.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2979.1107    282.109     10.560      0.000    2424.846    3533.376
# ...

# %%
vif = pd.DataFrame()
vif['features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values,i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by="VIF", ascending= False)
vif
# Out:
#      features    VIF
# 3         hum  21.59
# 2        temp  12.98
# 4   windspeed   3.94
# 5      spring   2.51
# 8        mist   2.23
# 6      winter   2.08
# 0          yr   2.05
# 7  light_rain   1.20
# 1     holiday   1.04

# %%
X_train_rfe = X_train_rfe.drop('hum',axis = 1)
X_train_sm = sm.add_constant(X_train_rfe)
lm = sm.OLS(y_train,X_train_sm)
lr_model = lm.fit()

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     284.7
# Date:                Wed, 10 Apr 2024   Prob (F-statistic):          6.44e-181
# Time:                        16:09:17   Log-Likelihood:                -4150.1
# No. Observations:                 510   AIC:                             8318.
# Df Residuals:                     501   BIC:                             8356.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2366.0097    212.823     11.117      0.000    1947.875    2784.145
# ...

# %%
vif = pd.DataFrame()
vif['features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values,i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by="VIF", ascending= False)
vif
# Out:
#      features   VIF
# 3   windspeed  3.91
# 2        temp  3.53
# 0          yr  2.05
# 4      spring  1.64
# 7        mist  1.49
# 5      winter  1.36
# 6  light_rain  1.08
# 1     holiday  1.04

# %% [markdown]
# ### Residual Analysis

# %%
y_train_pred = lr_model.predict(X_train_sm)
res = y_train - y_train_pred

# %%
sns.displot(res)

# %% [markdown]
# ### Prediction and Evaluation on Test Set

# %%
# pre-processing test data set

scale_column = ['mnth','weekday','temp','atemp','hum','windspeed']

data_test[scale_column] = scaler.transform(data_test[scale_column])

data_test.head()
# Out:
#      yr      mnth  holiday   weekday  workingday      temp     atemp  \
# 184   0  0.545455        1  0.166667           0  0.831783  0.769660
# 535   1  0.454545        0  0.500000           1  0.901354  0.842587
# 299   0  0.818182        0  0.666667           1  0.511964  0.496145
# 221   0  0.636364        0  0.500000           1  0.881625  0.795343
# 152   0  0.454545        0  0.666667           1  0.817246  0.741471
#
#           hum  windspeed   cnt  spring  summer  winter  light_rain  mist
# 184  0.657364   0.084219  6043       0       0       0           0     1
# 535  0.610133   0.153728  6211       0       1       0           0     0
# 299  0.837699   0.334206  2659       0       0       1           0     1
# 221  0.437098   0.339570  4780       0       0       0           0     0
# 152  0.314298   0.537414  4968       0       1       0           0     0

# %%
data_test.describe()
# Out:
#                yr        mnth     holiday     weekday  workingday        temp  \
# count  220.000000  220.000000  220.000000  220.000000  220.000000  220.000000
# mean     0.481818    0.499174    0.036364    0.502273    0.700000    0.558718
# std      0.500809    0.311120    0.187620    0.330843    0.459303    0.233187
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.046591
# 25%      0.000000    0.272727    0.000000    0.166667    0.000000    0.355429
# 50%      0.000000    0.454545    0.000000    0.500000    1.000000    0.558172
# 75%      1.000000    0.727273    0.000000    0.833333    1.000000    0.755981
# max      1.000000    1.000000    1.000000    1.000000    1.000000    0.984424
#
#             atemp         hum   windspeed          cnt      spring  \
# count  220.000000  220.000000  220.000000   220.000000  220.000000
# mean     0.532847    0.638221    0.313293  4560.559091    0.254545
# ...

# %%
y_test = data_test.pop('cnt')
X_test = data_test

# %%
X_test_sm = sm.add_constant(X_test)
X_test_sm.head()
# Out:
#      const  yr      mnth  holiday   weekday  workingday      temp     atemp  \
# 184    1.0   0  0.545455        1  0.166667           0  0.831783  0.769660
# 535    1.0   1  0.454545        0  0.500000           1  0.901354  0.842587
# 299    1.0   0  0.818182        0  0.666667           1  0.511964  0.496145
# 221    1.0   0  0.636364        0  0.500000           1  0.881625  0.795343
# 152    1.0   0  0.454545        0  0.666667           1  0.817246  0.741471
#
#           hum  windspeed  spring  summer  winter  light_rain  mist
# 184  0.657364   0.084219       0       0       0           0     1
# 535  0.610133   0.153728       0       1       0           0     0
# 299  0.837699   0.334206       0       0       1           0     1
# 221  0.437098   0.339570       0       0       0           0     0
# 152  0.314298   0.537414       0       1       0           0     0

# %%
X_test_sm = X_test_sm.drop(['mnth','weekday','workingday','atemp','hum','summer'], axis = 1)

# %%
y_test_pred = lr_model.predict(X_test_sm)

# %% [markdown]
# ### predictibility of the model on test dataset

# %%
r2_score(y_true = y_test, y_pred = y_test_pred)
# Out:
# 0.8018826530251253
